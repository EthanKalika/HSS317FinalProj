# %% [markdown]
# First lets load the data and import libraries.

# %%
import pandas as pd

data1 = pd.read_csv("data/nba_2022-23_all_stats_with_salary.csv")

print(data1.shape)
data1.head()
# Out:
# (467, 52)
#    Unnamed: 0        Player Name    Salary Position  Age     Team  GP  GS  \
# 0           0      Stephen Curry  48070014       PG   34      GSW  56  56
# 1           1          John Wall  47345760       PG   32      LAC  34   3
# 2           2  Russell Westbrook  47080179       PG   34  LAL/LAC  73  24
# 3           3       LeBron James  44474988       PF   38      LAL  55  54
# 4           4       Kevin Durant  44119845       PF   34  BRK/PHO  47  47
#
#      MP    FG  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  34.7  10.0  ...  12.5  31.0  5.8  2.0  7.8  0.192   7.5   0.1  7.5   4.7
# 1  22.2   4.1  ...  17.1  27.0 -0.4  0.7  0.3  0.020  -0.8  -0.4 -1.2   0.1
# 2  29.1   5.9  ...  18.4  27.7 -0.6  2.6  1.9  0.044   0.3  -0.1  0.2   1.2
# 3  35.5  11.1  ...  11.6  33.3  3.2  2.4  5.6  0.138   5.5   0.6  6.1   4.0
# 4  35.6  10.3  ...  13.4  30.7  4.7  2.1  6.8  0.194   6.0   1.2  7.1   3.9
#
# [5 rows x 52 columns]

# %% [markdown]
# Now lets drop the columns that we will not use.

# %%
data1 = data1.drop(columns = ['Unnamed: 0', 'Player Name', 'Team', 'GP', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '2P', '2PA', 'eFG%', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', '3PAr', 'FTr', 'USG%', 'OWS', 'WS', 'DWS', 'OBPM', 'BPM', 'VORP', 'DBPM'])
print(data1.shape)
data1.head()
# Out:
# (467, 17)
#      Salary Position  Age    3P%    2P%    FT%  Total Minutes   PER    TS%  \
# 0  48070014       PG   34  0.427  0.579  0.915           1941  24.1  0.656
# 1  47345760       PG   32  0.303  0.459  0.681            755  13.6  0.498
# 2  47080179       PG   34  0.311  0.487  0.656           2126  16.1  0.513
# 3  44474988       PF   38  0.321  0.580  0.768           1954  23.9  0.583
# 4  44119845       PF   34  0.404  0.617  0.919           1672  25.9  0.677
#
#    ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  WS/48
# 0   2.3  16.8   9.7  30.0   1.3   0.9  12.5  0.192
# 1   2.1  11.4   6.8  35.3   1.8   1.4  17.1  0.020
# 2   4.7  16.5  10.8  38.6   1.7   1.3  18.4  0.044
# 3   3.7  20.8  12.5  33.5   1.2   1.4  11.6  0.138
# 4   1.2  19.5  10.5  24.5   1.0   3.4  13.4  0.194

# %% [markdown]
# Now lets deal with the position categorical variable

# %%
data1['SG'] = 0
data1['PF'] = 0
data1['C'] = 0
data1['SF'] = 0
data1['PG'] = 0

for index, row in data1.iterrows():
  currPos = row['Position'].split("-")
  for i in currPos:
    if i == 'SG':
      data1.at[index, 'SG'] = 1
    elif i == 'PF':
      data1.at[index, 'PF'] = 1
    elif i == 'C':
      data1.at[index, 'C'] = 1
    elif i == 'SF':
      data1.at[index, 'SF'] = 1
    elif i == 'PG':
      data1.at[index, 'PG'] = 1

data1 = data1.drop(columns = ['Position'])

data1.head()
# Out:
#      Salary  Age    3P%    2P%    FT%  Total Minutes   PER    TS%  ORB%  DRB%  \
# 0  48070014   34  0.427  0.579  0.915           1941  24.1  0.656   2.3  16.8
# 1  47345760   32  0.303  0.459  0.681            755  13.6  0.498   2.1  11.4
# 2  47080179   34  0.311  0.487  0.656           2126  16.1  0.513   4.7  16.5
# 3  44474988   38  0.321  0.580  0.768           1954  23.9  0.583   3.7  20.8
# 4  44119845   34  0.404  0.617  0.919           1672  25.9  0.677   1.2  19.5
#
#    ...  AST%  STL%  BLK%  TOV%  WS/48  SG  PF  C  SF  PG
# 0  ...  30.0   1.3   0.9  12.5  0.192   0   0  0   0   1
# 1  ...  35.3   1.8   1.4  17.1  0.020   0   0  0   0   1
# 2  ...  38.6   1.7   1.3  18.4  0.044   0   0  0   0   1
# 3  ...  33.5   1.2   1.4  11.6  0.138   0   1  0   0   0
# 4  ...  24.5   1.0   3.4  13.4  0.194   0   1  0   0   0
#
# [5 rows x 21 columns]

# %% [markdown]
# Now lets normalize the data.

# %%
maxSal = data1['Salary'].max()
data1Norm = data1/data1.max() * 10

for index, row in data1Norm.iterrows():
  data1Norm.at[index, 'Salary'] = row['Salary'] * maxSal / 1000000

print(data1Norm.head())
# Out:
#       Salary       Age   3P%   2P%   FT%  Total Minutes       PER       TS%  \
# 0  480.70014  8.095238  4.27  5.79  9.15       6.550793  3.673780  6.165414
# 1  473.45760  7.619048  3.03  4.59  6.81       2.548093  2.073171  4.680451
# 2  470.80179  8.095238  3.11  4.87  6.56       7.175160  2.454268  4.821429
# 3  444.74988  9.047619  3.21  5.80  7.68       6.594668  3.643293  5.479323
# 4  441.19845  8.095238  4.04  6.17  9.19       5.642929  3.948171  6.362782
#
#        ORB%      DRB%  ...      AST%      STL%      BLK%  TOV%     WS/48   SG  \
# 0  0.798611  3.032491  ...  6.302521  0.537190  0.204082  1.25  3.067093  0.0
# 1  0.729167  2.057762  ...  7.415966  0.743802  0.317460  1.71  0.319489  0.0
# 2  1.631944  2.978339  ...  8.109244  0.702479  0.294785  1.84  0.702875  0.0
# 3  1.284722  3.754513  ...  7.037815  0.495868  0.317460  1.16  2.204473  0.0
# 4  0.416667  3.519856  ...  5.147059  0.413223  0.770975  1.34  3.099042  0.0
#
#      PF    C   SF    PG
# ...

# %% [markdown]
# Lets add an age^2 column. This will help account for the fact that more extreme ages result in less favorable pay.

# %%
data1Norm['Age^2'] = data1Norm['Age'] ** 2
data1Norm = data1Norm.fillna(0)
data1Norm.to_csv("data/finaldata.csv")
data1Norm.head()
# Out:
#       Salary       Age   3P%   2P%   FT%  Total Minutes       PER       TS%  \
# 0  480.70014  8.095238  4.27  5.79  9.15       6.550793  3.673780  6.165414
# 1  473.45760  7.619048  3.03  4.59  6.81       2.548093  2.073171  4.680451
# 2  470.80179  8.095238  3.11  4.87  6.56       7.175160  2.454268  4.821429
# 3  444.74988  9.047619  3.21  5.80  7.68       6.594668  3.643293  5.479323
# 4  441.19845  8.095238  4.04  6.17  9.19       5.642929  3.948171  6.362782
#
#        ORB%      DRB%  ...      STL%      BLK%  TOV%     WS/48   SG    PF  \
# 0  0.798611  3.032491  ...  0.537190  0.204082  1.25  3.067093  0.0   0.0
# 1  0.729167  2.057762  ...  0.743802  0.317460  1.71  0.319489  0.0   0.0
# 2  1.631944  2.978339  ...  0.702479  0.294785  1.84  0.702875  0.0   0.0
# 3  1.284722  3.754513  ...  0.495868  0.317460  1.16  2.204473  0.0  10.0
# 4  0.416667  3.519856  ...  0.413223  0.770975  1.34  3.099042  0.0  10.0
#
#      C   SF    PG      Age^2
# 0  0.0  0.0  10.0  65.532880
# ...
